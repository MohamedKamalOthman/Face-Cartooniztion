# %%
import skimage.io as io
import scipy.fft as fft
import cv2
from ffextractor import FeaturesLocator
import commonfunctions as cf
import numpy as np
import imutils
from filters import *

# %%
def test_filters(img1):
    img2 = np.copy(img1)
    img3 = np.copy(img1)
    img4 = np.copy(img1)
    render_filter_0(img1)
    render_filter_1(img2)
    render_filter_2(img3)
    render_filter_3(img4)
    cf.show_images([img1, img2, img3, img4])

# %%
test_filters(io.imread(f"../rock.jpg"))

# %%
test_filters(io.imread(f"../r.jpg"))

# %%
test_filters(io.imread(f"../img.jpg"))

# %%
test_filters(io.imread(f"../abdulhady.jpeg"))

# %%
test_filters(io.imread(f"../kotb.jpeg"))

# %%
test_filters(io.imread(f"../kamal.jpg"))

# %%
test_filters(io.imread(f"../karim.jpg"))

# %%
# # live feed
# # define a video capture object
# vid = cv2.VideoCapture(0)

# while True:

#     # Capture the video frame
#     # by frame
#     ret, frame = vid.read()
#     frame = render_filter_0(frame)
#     # Display the resulting frame
#     cv2.imshow("frame", frame)

#     # the 'q' button is set as the
#     # quitting button you may use any
#     # desired button of your choice
#     if cv2.waitKey(1) & 0xFF == ord("q"):
#         break

# # After the loop release the cap object
# vid.release()
# # Destroy all the windows
# cv2.destroyAllWindows()
